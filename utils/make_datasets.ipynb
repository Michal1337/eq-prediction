# %%
import numpy as np
import tensorflow as tf
import tqdm
import os
import gc
# Out:
# 2023-10-29 04:13:15.127433: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2023-10-29 04:13:17.464256: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT

# %%
input_directory = '../data/npys/'
output_directory = '../data/datasets/'

# %%
for idx in tqdm.tqdm(range(1349)):
    for split in ['train', 'val', 'test']:
        x = np.load(os.path.join(input_directory, f"x_{split}_{idx}.npy"))
        y = np.load(os.path.join(input_directory, f"y_{split}_{idx}.npy"))
        dataset = tf.data.Dataset.from_tensor_slices((x, y))
        dataset.save(os.path.join(output_directory, f"{split}_{idx}"))
# Out:
# 100%|██████████| 1349/1349 [00:01<00:00, 1248.89it/s]
